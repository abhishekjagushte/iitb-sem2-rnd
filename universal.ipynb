# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
def average_eight_streaks(strides):
    streak_lengths = []
    current_streak = 0

    for num in strides:
        if num == 8:
            current_streak += 1
        else:
            if current_streak > 0:
                streak_lengths.append(current_streak)
            current_streak = 0

    if current_streak > 0:
        streak_lengths.append(current_streak)

    if streak_lengths:
        average_streak = sum(streak_lengths) / len(streak_lengths)
        return average_streak
    else:
        return 0

# %%
def get_average_streak_length(strides):
    if not strides:
        return 0
    
    streak_lengths = []
    current_streak = 1

    for i in range(1, len(strides)):
        if strides[i] == strides[i - 1]:
            current_streak += 1
        else:
            streak_lengths.append(current_streak)
            current_streak = 1

    streak_lengths.append(current_streak)

    if streak_lengths:
        average_streak = sum(streak_lengths) / len(streak_lengths)
        return average_streak
    else:
        return 0

# %%
def calculate_strides(group):
    strides = group['vpn'].diff().dropna()
    return strides

def average_streak_length(strides):
    if strides.empty:
        return 0

    streak_lengths = []
    current_streak = 1

    for i in range(1, len(strides)):
        if strides.iloc[i] == strides.iloc[i - 1]:
            current_streak += 1
        else:
            streak_lengths.append(current_streak)
            current_streak = 1

    streak_lengths.append(current_streak)

    average_streak = sum(streak_lengths) / len(streak_lengths)
    return average_streak

def process_dataframe(df):
    grouped = df.groupby('eip').apply(calculate_strides).reset_index(level=0, drop=True)
    average_streaks = grouped.groupby(df['eip']).apply(average_streak_length)
    return average_streaks

# %%
def total_strides_per_eip(df):
    total_entries = df.groupby('eip').size()
    total_strides = total_entries - 1
    return total_strides

# %%
def analyse_workload(name):

    print("---------------------------------------------")
    print(f"Analyzing {name} workload...")
    print("---------------------------------------------")
    
    df = pd.read_csv('./data/'+name+'_full.csv')
    num_unique_eip = df['eip'].nunique()

    print(f"The number of unique 'eip' values is: {num_unique_eip}")

    my_strides = []
    my_list = df['vpn'].to_list()

    my_eips = df['eip'].to_list()

    for i in range(len(my_list)-1):
        stride = my_list[i+1] - my_list[i]
        my_strides.append(stride)

    strides = pd.Series(my_strides)

    # Stride frequency analysis
    stride_counts = strides.value_counts()
    total_strides = len(strides.to_list())
    print("Stride Frequency:")
    i = 0
    sum = 0
    for stride, count in stride_counts.items():
        if i > 10:
            break
        print(f"Stride: {stride}, Fraction: {count/total_strides}")
        sum += count/total_strides
        i += 1

    print("Sum of fractions of top 10 strides:", sum)

    # # Plot the stride-fraction distribution
    # fig = px.bar(x=stride_counts.index, y=stride_counts.values/total_strides, labels={'x':'Stride', 'y':'Fraction'})
    
    # # Save it in 'plots' directory
    # fig.write_image(f'./plots/{name}_stride_frequency.png')

    # Total stride count
    print("Total Strides:", total_strides)

    # Number of unique strides
    print("Number of Unique Strides:", len(stride_counts))

    # Number of strides for which sum of fractions is greater than 0.5
    sum_fraction = 0
    i = 0
    for stride, count in stride_counts.items():
        sum_fraction += count/total_strides
        i += 1
        if sum_fraction > 0.5:
            break
    print("Number of strides for which sum of fractions is greater than 0.5:", i)

    average_streak = get_average_streak_length(my_strides)
    print(f"The average length of any streak is: {average_streak}")

    # Process the DataFrame and get average streak lengths by 'eip'
    average_streaks_by_eip = process_dataframe(df)
    total_strides_by_eip = total_strides_per_eip(df)

    total_strides_by_eip_df = pd.DataFrame({'eip': total_strides_by_eip.index, 'total_strides': total_strides_by_eip.values})
    average_streaks_by_eip_df = pd.DataFrame({'eip': average_streaks_by_eip.index, 'average_streak': average_streaks_by_eip.values})

    merged = pd.merge(total_strides_by_eip_df, average_streaks_by_eip_df, on='eip')

    sorted_df = merged.sort_values('average_streak', ascending=False)
    print("Average Streaks by 'eip':")
    print(sorted_df)
    print("")

# %%
analyse_workload("bc")
analyse_workload("bfs")
analyse_workload("cc")
analyse_workload("dlrm")
analyse_workload("gc")
analyse_workload("gen")
analyse_workload("pr")
analyse_workload("rnd")
analyse_workload("sssp")
analyse_workload("tc")
analyse_workload("xs")
# Out:
# ---------------------------------------------
# Analyzing bc workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 49
# Stride Frequency:
# Stride: 34, Fraction: 0.003129446477618355
# Stride: 35, Fraction: 0.0029751722205854283
# Stride: 11, Fraction: 0.002943771265614125
# Stride: 33, Fraction: 0.0026324922337246804
# Stride: 10, Fraction: 0.002376096610089427
# Stride: 36, Fraction: 0.002360532658494955
# Stride: 12, Fraction: 0.002326947289264778
# Stride: 14, Fraction: 0.0022903583504286502
# Stride: 13, Fraction: 0.0021186087793247377
# Stride: 105, Fraction: 0.0021172435204129415
# Stride: 106, Fraction: 0.0020934880153476946
# Sum of fractions of top 10 strides: 0.02736415742090577
# Total Strides: 3662309
# Number of Unique Strides: 1008865
# Number of strides for which sum of fractions is greater than 0.5: 2526
# The average length of any streak is: 1.0013564473492815
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 18  140461382775704            272      272.000000
# 23  140461383287890            261      261.000000
# 1    93907474509834           2848      189.866667
# 6    93907474510098            125      125.000000
# 8    93907474510130            113      113.000000
# 4    93907474509917            140       70.000000
# 2    93907474509887            747       57.461538
# 3    93907474509908            810       47.647059
# 20  140461382781116           1298       16.430380
# 5    93907474509968             90        4.090909
# 16   93907474511444             11        3.666667
# 12   93907474510194           7589        3.457403
# 17   93907474537275              7        2.333333
# 26  140461383776494              2        2.000000
# 19  140461382776058             28        1.555556
# 13   93907474510235          74633        1.176843
# 7    93907474510125            464        1.165829
# 28  140461387296452         293514        1.066319
# 15   93907474510289            513        1.005882
# 29  140461387296467          47552        1.001601
# 11   93907474510177        3229618        1.001427
# 25  140461383776489              1        1.000000
# 30  140461722858837              2        1.000000
# 27  140461387161412              1        1.000000
# 0    93907474500912              1        1.000000
# 24  140461383776389              1        1.000000
# 22  140461382787738              1        1.000000
# 21  140461382787684              1        1.000000
# 14   93907474510285            744        1.000000
# 10   93907474510168            869        1.000000
# 9    93907474510144              2        1.000000
# 31  140461722858895              3        1.000000
#
# ---------------------------------------------
# Analyzing bfs workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 46
# Stride Frequency:
# Stride: -1, Fraction: 0.007702780176561359
# Stride: 1, Fraction: 0.00027884358183399193
# Stride: 99, Fraction: 0.00021071767986462886
# Stride: 198, Fraction: 0.00010224648908092222
# Stride: 528, Fraction: 0.00010005631625957214
# Stride: 627, Fraction: 8.824091024965722e-05
# Stride: -2, Fraction: 1.2334131151813616e-05
# Stride: 2, Fraction: 4.553254023333063e-06
# Stride: 4, Fraction: 4.4956178964554305e-06
# Stride: -3, Fraction: 4.265073388944895e-06
# Stride: -5, Fraction: 3.458167612658023e-06
# Sum of fractions of top 10 strides: 0.008511991397923333
# Total Strides: 17350229
# Number of Unique Strides: 4714676
# Number of strides for which sum of fractions is greater than 0.5: 778457
# The average length of any streak is: 1.0000004610892277
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 19  140737003402203            249      249.000000
# 17  140737003399349             45        9.000000
# 24  140737003406977            970        8.083333
# 29  140737017118480              5        5.000000
# 22  140737003405565             27        3.857143
# 18  140737003399401            226        3.587302
# 25  140737003413299              3        3.000000
# 1    93824992699086            704        2.362416
# 20  140737003402533             34        2.125000
# 16  140737003399323              8        2.000000
# 12   93824992699799             12        1.333333
# 11   93824992699771              8        1.142857
# 4    93824992699158         394058        1.000071
# 5    93824992699189       14796801        1.000001
# 0    93824992689424              1        1.000000
# 21  140737003404984              2        1.000000
# 26  140737003413469              1        1.000000
# 27  140737003414820             11        1.000000
# 28  140737004126319             48        1.000000
# 23  140737003406771              3        1.000000
# 15  140737003399252              1        1.000000
# 14  140737003397704              4        1.000000
# 13   93824992700075              2        1.000000
# 10   93824992699640           1399        1.000000
# 9    93824992699636             10        1.000000
# 8    93824992699249            905        1.000000
# 7    93824992699233            514        1.000000
# 6    93824992699208         206191        1.000000
# 3    93824992699136        1157848        1.000000
# 2    93824992699111         790090        1.000000
# 30  140737351918613              4        1.000000
#
# ---------------------------------------------
# Analyzing cc workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 46
# Stride Frequency:
# Stride: -1, Fraction: 0.006457159686053738
# Stride: 1, Fraction: 0.0004720694450015944
# Stride: 99, Fraction: 0.00031836692227211924
# Stride: 2, Fraction: 5.339189999517583e-06
# Stride: 4, Fraction: 4.772196371250229e-06
# Stride: -5, Fraction: 2.598720796225372e-06
# Stride: -3, Fraction: 2.220725044047136e-06
# Stride: -7, Fraction: 2.1734755750248567e-06
# Stride: -8, Fraction: 2.1262261060025772e-06
# Stride: -4, Fraction: 2.1262261060025772e-06
# Stride: 33, Fraction: 2.0789766369802978e-06
# Sum of fractions of top 10 strides: 0.007271031789962502
# Total Strides: 21164259
# Number of Unique Strides: 5059007
# Number of strides for which sum of fractions is greater than 0.5: 770820
# The average length of any streak is: 1.0000002834968944
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 16  140737003406299            264      264.000000
# 22  140737003411073           1065       10.047170
# 14  140737003403445             58        9.666667
# 25  140737003417565              4        4.000000
# 15  140737003403497            304        3.040000
# 28  140737017122576              3        3.000000
# 24  140737003417395              3        3.000000
# 17  140737003406629             36        2.571429
# 1    93824992698577            926        2.362245
# 20  140737003409661             19        1.583333
# 13  140737003403419              9        1.500000
# 11   93824992699102              3        1.500000
# 10   93824992698848             24        1.263158
# 4    93824992698646         374184        1.000078
# 5    93824992698673       17971400        1.000000
# 23  140737003417373              1        1.000000
# 26  140737003418916              6        1.000000
# 27  140737004130415             46        1.000000
# 29  140737351918560              1        1.000000
# 21  140737003410867             10        1.000000
# 0    93824992689424              1        1.000000
# 19  140737003409080              3        1.000000
# 18  140737003408652              1        1.000000
# 12  140737003401800              2        1.000000
# 9    93824992698826             11        1.000000
# 8    93824992698722           2332        1.000000
# 7    93824992698695            689        1.000000
# 6    93824992698688         252166        1.000000
# 3    93824992698624        1496860        1.000000
# 2    93824992698602        1063779        1.000000
# 30  140737351918613              4        1.000000
#
# ---------------------------------------------
# Analyzing dlrm workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 43
# Stride Frequency:
# Stride: -1, Fraction: 0.007727362411782487
# Stride: 1, Fraction: 0.00028130401813248934
# Stride: 99, Fraction: 0.00021187407037722428
# Stride: 198, Fraction: 0.0001026129535933351
# Stride: 528, Fraction: 9.949120739950969e-05
# Stride: 627, Fraction: 8.983691824453112e-05
# Stride: -2, Fraction: 1.208231397239833e-05
# Stride: 2, Fraction: 4.624809176037638e-06
# Stride: 4, Fraction: 4.509188946636697e-06
# Stride: -3, Fraction: 4.220138373134345e-06
# Stride: -5, Fraction: 3.2951765379268172e-06
# Sum of fractions of top 10 strides: 0.00854121320653571
# Total Strides: 17298011
# Number of Unique Strides: 4650141
# Number of strides for which sum of fractions is greater than 0.5: 774536
# The average length of any streak is: 1.0000004046709667
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 19  140737003402203            249      249.000000
# 17  140737003399349             43        8.600000
# 24  140737003406977            968        8.203390
# 22  140737003405565             26        3.714286
# 18  140737003399401            224        3.612903
# 26  140737003413469              3        3.000000
# 25  140737003413299              3        3.000000
# 1    93824992699086            692        2.419580
# 20  140737003402533             35        2.058824
# 0    93824992689424              2        2.000000
# 29  140737017118480              2        2.000000
# 16  140737003399323              9        1.800000
# 11   93824992699771              9        1.500000
# 12   93824992699799             12        1.200000
# 4    93824992699158         349882        1.000080
# 5    93824992699189       14789135        1.000000
# 27  140737003414820              6        1.000000
# 21  140737003404984              2        1.000000
# 28  140737004126319             47        1.000000
# 23  140737003406771              4        1.000000
# 15  140737003399252              1        1.000000
# 14  140737003397704              4        1.000000
# 13   93824992700075              2        1.000000
# 10   93824992699640           1399        1.000000
# 9    93824992699636             10        1.000000
# 8    93824992699249            908        1.000000
# 7    93824992699233            514        1.000000
# 6    93824992699208         206062        1.000000
# 3    93824992699136        1157869        1.000000
# 2    93824992699111         789843        1.000000
# 30  140737351918613              4        1.000000
#
# ---------------------------------------------
# Analyzing gc workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 59
# Stride Frequency:
# Stride: -1, Fraction: 0.0031758780798095696
# Stride: 8192, Fraction: 2.925206644955133e-05
# Stride: -8200, Fraction: 2.7253478058588194e-05
# Stride: 11196151768, Fraction: 2.7192914774013554e-05
# Stride: -11196151776, Fraction: 2.7132351489438914e-05
# Stride: -8, Fraction: 2.689009835114035e-05
# Stride: 2048, Fraction: 1.822954865696677e-05
# Stride: 10, Fraction: 1.7866168949518927e-05
# Stride: 9, Fraction: 1.7805605664944287e-05
# Stride: -11214883530, Fraction: 1.7381662672921804e-05
# Stride: 20, Fraction: 1.6049270412279714e-05
# Sum of fractions of top 10 strides: 0.003400931245288933
# Total Strides: 16511654
# Number of Unique Strides: 11042331
# Number of strides for which sum of fractions is greater than 0.5: 2786504
# The average length of any streak is: 1.0000281627204437
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 32  140101350426838            381      127.000000
# 29  140101350426824           1154      115.400000
# 33  140101350426857           1477       98.466667
# 36  140101350426874             94       31.333333
# 31  140101350426833             93       31.000000
# 3    94163319581398            667       23.000000
# 5    94163319581453          75939       18.594270
# 6    94163319581458             18       18.000000
# 12   94163319581665            724       16.088889
# 24  140101349438052             10       10.000000
# 41  140101353733956              9        9.000000
# 20  140101349428535              9        9.000000
# 1    94163319574336              9        9.000000
# 25  140101349438133              8        8.000000
# 21  140101349429427              8        8.000000
# 35  140101350426868             21        7.000000
# 30  140101350426828             20        6.666667
# 13   94163319581681              5        5.000000
# 38  140101350426923              3        3.000000
# 26  140101349439576              2        2.000000
# 27  140101349439583              2        2.000000
# 28  140101349439619              2        2.000000
# 0    94163319574256              2        2.000000
# 17   94163319603520              2        2.000000
# 15   94163319581964              2        2.000000
# 42  140101353736644              2        2.000000
# 18  140101349424047              2        2.000000
# 34  140101350426862              3        1.500000
# 4    94163319581423            252        1.229268
# 9    94163319581524         363626        1.000426
# 10   94163319581557        6192181        1.000070
# 8    94163319581512        9796530        1.000002
# 37  140101350426915              3        1.000000
# 39  140101351261044              1        1.000000
# 40  140101351261051              1        1.000000
# 43  140101689501013              3        1.000000
# 22  140101349429465              8        1.000000
# 23  140101349431484             10        1.000000
# 19  140101349425408              2        1.000000
# 16   94163319603494              9        1.000000
# 14   94163319581952           3357        1.000000
# 11   94163319581575          74941        1.000000
# 7    94163319581475              1        1.000000
# 2    94163319575136              1        1.000000
# 44  140101689501071              2        1.000000
#
# ---------------------------------------------
# Analyzing gen workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 59
# Stride Frequency:
# Stride: -1, Fraction: 0.0031819880259013134
# Stride: 8192, Fraction: 2.9064228129486223e-05
# Stride: 11196151768, Fraction: 2.7187163396123572e-05
# Stride: -8200, Fraction: 2.7126612920853808e-05
# Stride: -11196151776, Fraction: 2.7126612920853808e-05
# Stride: -8, Fraction: 2.694496149504452e-05
# Stride: 2048, Fraction: 1.840734448200794e-05
# Stride: 9, Fraction: 1.8044041630389364e-05
# Stride: 10, Fraction: 1.774128925404055e-05
# Stride: -11214883530, Fraction: 1.7256885451882445e-05
# Stride: 20, Fraction: 1.556147214432908e-05
# Sum of fractions of top 10 strides: 0.003406448637726325
# Total Strides: 16515147
# Number of Unique Strides: 11045241
# Number of strides for which sum of fractions is greater than 0.5: 2787668
# The average length of any streak is: 1.0000283384254698
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 31  140101350426838            381      127.000000
# 28  140101350426824           1154      115.400000
# 32  140101350426857           1477       98.466667
# 35  140101350426874             93       31.000000
# 30  140101350426833             93       31.000000
# 5    94163319581453          75923       18.590353
# 6    94163319581458             18       18.000000
# 3    94163319581398            669       17.153846
# 11   94163319581665            726       16.133333
# 23  140101349438052              9        9.000000
# 40  140101353733956              9        9.000000
# 19  140101349428535              9        9.000000
# 1    94163319574336              9        9.000000
# 24  140101349438133              8        8.000000
# 20  140101349429427              8        8.000000
# 34  140101350426868             21        7.000000
# 29  140101350426828             20        6.666667
# 12   94163319581681              4        4.000000
# 14   94163319581964              3        3.000000
# 37  140101350426923              3        3.000000
# 27  140101349439619              2        2.000000
# 26  140101349439583              2        2.000000
# 25  140101349439576              2        2.000000
# 0    94163319574256              2        2.000000
# 17  140101349424047              2        2.000000
# 16   94163319603520              2        2.000000
# 41  140101353736644              2        2.000000
# 33  140101350426862              3        1.500000
# 4    94163319581423            258        1.277228
# 8    94163319581524         364880        1.000455
# 9    94163319581557        6195126        1.000068
# 7    94163319581512        9795960        1.000002
# 36  140101350426915              3        1.000000
# 39  140101351261051              1        1.000000
# 42  140101689501013              3        1.000000
# 38  140101351261044              1        1.000000
# 22  140101349431484             10        1.000000
# 21  140101349429465              8        1.000000
# 18  140101349425408              2        1.000000
# 15   94163319603494              9        1.000000
# 13   94163319581952           3359        1.000000
# 10   94163319581575          74812        1.000000
# 2    94163319575136              1        1.000000
# 43  140101689501071              2        1.000000
#
# ---------------------------------------------
# Analyzing pr workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 28
# Stride Frequency:
# Stride: 8, Fraction: 0.02383164256114316
# Stride: -1, Fraction: 0.011287310074270111
# Stride: 9, Fraction: 0.005777947079712023
# Stride: 7, Fraction: 0.005765279067420939
# Stride: 6, Fraction: 0.003459700830443767
# Stride: 10, Fraction: 0.003412584714554124
# Stride: 5, Fraction: 0.0021210030754377908
# Stride: 11, Fraction: 0.0021047791298720174
# Stride: 12, Fraction: 0.0013376976487724697
# Stride: 4, Fraction: 0.00133525294464612
# Stride: 13, Fraction: 0.0008534239859256161
# Sum of fractions of top 10 strides: 0.06128662111219814
# Total Strides: 8999044
# Number of Unique Strides: 2164941
# Number of strides for which sum of fractions is greater than 0.5: 502138
# The average length of any streak is: 1.0190713416661457
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 0    93824992696682           1691       76.863636
# 4    93824992696829          26719       13.528608
# 6    93824992696912          94176        5.119374
# 5    93824992696852            107        3.451613
# 1    93824992696717         510757        1.513856
# 7    93824992696924          65017        1.000062
# 9    93824992696972         107496        1.000009
# 8    93824992696953        8181607        1.000000
# 2    93824992696739          11436        1.000000
# 3    93824992696798              2        1.000000
# 10   93824992697014              7        1.000000
# 11  140737351918613              2        1.000000
#
# ---------------------------------------------
# Analyzing rnd workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 2
# Stride Frequency:
# Stride: 32768, Fraction: 1.4504344388454676e-05
# Stride: -10786, Fraction: 1.4504344388454676e-05
# Stride: -224, Fraction: 1.4167034053839452e-05
# Stride: 2053, Fraction: 1.4167034053839452e-05
# Stride: -5723, Fraction: 1.3829723719224227e-05
# Stride: 13292, Fraction: 1.3829723719224227e-05
# Stride: 2306, Fraction: 1.3829723719224227e-05
# Stride: 1321, Fraction: 1.3492413384609001e-05
# Stride: -1941, Fraction: 1.3492413384609001e-05
# Stride: -4649, Fraction: 1.3492413384609001e-05
# Stride: 7587, Fraction: 1.3155103049993777e-05
# Sum of fractions of top 10 strides: 0.00015246427124608172
# Total Strides: 2964629
# Number of Unique Strides: 251211
# Number of strides for which sum of fractions is greater than 0.5: 71673
# The average length of any streak is: 1.0000016865545176
# Average Streaks by 'eip':
#               eip  total_strides  average_streak
# 0  93824992234609        2964628        1.000002
#
# ---------------------------------------------
# Analyzing sssp workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 52
# Stride Frequency:
# Stride: -1, Fraction: 0.003522451098521961
# Stride: 10, Fraction: 0.0024487879616114793
# Stride: 9, Fraction: 0.0019816930538687216
# Stride: 11, Fraction: 0.0019660063422297903
# Stride: 8, Fraction: 0.0019514730652701925
# Stride: 1, Fraction: 0.0018738699800446572
# Stride: 7, Fraction: 0.0016739105440354602
# Stride: 12, Fraction: 0.0016676358593798878
# Stride: 20, Fraction: 0.0016670360733466345
# Stride: 15, Fraction: 0.0016580392828478357
# Stride: 6, Fraction: 0.0016543021544867963
# Sum of fractions of top 10 strides: 0.022065205415643413
# Total Strides: 21674396
# Number of Unique Strides: 9689150
# Number of strides for which sum of fractions is greater than 0.5: 199279
# The average length of any streak is: 1.0004903116142183
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 25   94320874787140            762       30.480000
# 2    94320874755019            183       20.333333
# 24   94320874787133            846       19.227273
# 38  140251933282970              9        9.000000
# 1    94320874745312              9        9.000000
# 31  140251933270936              8        8.000000
# 33  140251933273399              7        7.000000
# 39  140251933282997              7        7.000000
# 37  140251933282916              7        7.000000
# 19   94320874755594            255        6.538462
# 44  140251937578820              6        6.000000
# 34  140251933274291              7        3.500000
# 17   94320874755546            427        2.033333
# 40  140251933284440              2        2.000000
# 29  140251933268911              2        2.000000
# 28  140251933268433              2        2.000000
# 26   94320874787181              2        2.000000
# 41  140251933284447              2        2.000000
# 43  140251933284483              2        2.000000
# 0    94320874745248              2        2.000000
# 45  140251937581508              2        2.000000
# 9    94320874755234              2        2.000000
# 16   94320874755525            140        1.186441
# 7    94320874755196         425573        1.084442
# 11   94320874755252             30        1.034483
# 18   94320874755550             50        1.020408
# 3    94320874755107            260        1.015625
# 21   94320874786683           2428        1.010824
# 5    94320874755160            108        1.009346
# 8    94320874755229        8697617        1.005936
# 4    94320874755141           5367        1.004304
# 13   94320874755282         100878        1.000337
# 6    94320874755184       12301832        1.000175
# 14   94320874755286            512        1.000000
# 20   94320874755616            774        1.000000
# 42  140251933284464              1        1.000000
# 15   94320874755302           5194        1.000000
# 27  140251933264804              1        1.000000
# 36  140251933276348              2        1.000000
# 35  140251933274329              2        1.000000
# 10   94320874755244           5850        1.000000
# 22   94320874786697              6        1.000000
# 32  140251933271290              7        1.000000
# 12   94320874755267         125151        1.000000
# 30  140251933270272              2        1.000000
# 23   94320874787105              9        1.000000
#
# ---------------------------------------------
# Analyzing tc workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 11
# Stride Frequency:
# Stride: -1, Fraction: 0.005529122613421804
# Stride: 1, Fraction: 0.0020811463457452717
# Stride: 99, Fraction: 0.0001482374522146944
# Stride: 198, Fraction: 8.374744279198748e-05
# Stride: 627, Fraction: 7.61340389018068e-05
# Stride: 528, Fraction: 7.434264975117604e-05
# Stride: -34314777141, Fraction: 1.3883265917388297e-05
# Stride: -34314782300, Fraction: 1.2091876766757549e-05
# Stride: -34314781963, Fraction: 1.0748334903784488e-05
# Stride: -34314777144, Fraction: 1.0748334903784488e-05
# Stride: -34314775793, Fraction: 1.0300487616126802e-05
# Sum of fractions of top 10 strides: 0.008050502842934584
# Total Strides: 2232904
# Number of Unique Strides: 1484711
# Number of strides for which sum of fractions is greater than 0.5: 418596
# The average length of any streak is: 1.0
# Average Streaks by 'eip':
#               eip  total_strides  average_streak
# 1  93824992698144          10191      207.979592
# 0  93824992698096           3547       30.059322
# 6  93824992698254            348        3.866667
# 2  93824992698169         212499        1.000019
# 5  93824992698251         944047        1.000004
# 3  93824992698205        1048528        1.000000
# 4  93824992698224          13333        1.000000
# 7  93824992698280            401        1.000000
#
# ---------------------------------------------
# Analyzing xs workload...
# ---------------------------------------------
# The number of unique 'eip' values is: 28
# Stride Frequency:
# Stride: 176, Fraction: 0.15752138623198167
# Stride: 175, Fraction: 0.08796421033724011
# Stride: 177, Fraction: 0.048726649153531816
# Stride: 352, Fraction: 0.045224022183304145
# Stride: 351, Fraction: 0.029049631775113386
# Stride: 528, Fraction: 0.02050776864699807
# Stride: 527, Fraction: 0.01638909470564462
# Stride: -10, Fraction: 0.015142967802775159
# Stride: 10, Fraction: 0.015023687637523014
# Stride: 174, Fraction: 0.012915936952714535
# Stride: 703, Fraction: 0.011424233239031838
# Sum of fractions of top 10 strides: 0.4598895886658584
# Total Strides: 712608
# Number of Unique Strides: 201008
# Number of strides for which sum of fractions is greater than 0.5: 16
# The average length of any streak is: 1.0747440988524226
# Average Streaks by 'eip':
#                 eip  total_strides  average_streak
# 0    94189867773552             34       34.000000
# 9   140202872921702             34       34.000000
# 7   140202872921684             33       33.000000
# 8   140202872921697             33       33.000000
# 3    94189867784143         477608        1.115224
# 1    94189867783926         112256        1.000027
# 2    94189867784112         121350        1.000000
# 4    94189867784156            247        1.000000
# 5    94189867784168            751        1.000000
# 6    94189867784181            225        1.000000
# 10  140203206783927              1        1.000000
# 11  140203206783956              1        1.000000
# 12  140203206784341              3        1.000000
# 13  140203206784399              3        1.000000
# 14  140203206807874              1        1.000000
# 15  140203206839228              1        1.000000
